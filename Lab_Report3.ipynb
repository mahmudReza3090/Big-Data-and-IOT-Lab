# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("credit card.csv")

# %%
df.fillna(0)
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE   AGE  PAY_0  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1  24.0      2      2     -1
# 1          2   120000.0    2          2         2  26.0     -1      2      0
# 2          3    90000.0    2          2         2   0.0      0      0      0
# 3          4    50000.0    2          2         1   0.0      0      0      0
# 4          5    50000.0    1          2         1  57.0     -1      0     -1
# ...      ...        ...  ...        ...       ...   ...    ...    ...    ...
# 29995  29996   220000.0    1          3         1  39.0      0      0      0
# 29996  29997   150000.0    1          3         2  43.0     -1     -1     -1
# 29997  29998    30000.0    1          2         2  37.0      4      3      2
# 29998  29999    80000.0    1          3         1  41.0      1     -1      0
# 29999  30000    50000.0    1          2         1  46.0      0      0      0
#
# ...

# %%
dummies=pd.get_dummies(df['LIMIT_BAL'])

# %%
merged=pd.concat([df,dummies],axis='columns')

# %%
merged
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE   AGE  PAY_0  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1  24.0      2      2     -1
# 1          2   120000.0    2          2         2  26.0     -1      2      0
# 2          3    90000.0    2          2         2   NaN      0      0      0
# 3          4    50000.0    2          2         1   NaN      0      0      0
# 4          5    50000.0    1          2         1  57.0     -1      0     -1
# ...      ...        ...  ...        ...       ...   ...    ...    ...    ...
# 29995  29996   220000.0    1          3         1  39.0      0      0      0
# 29996  29997   150000.0    1          3         2  43.0     -1     -1     -1
# 29997  29998    30000.0    1          2         2  37.0      4      3      2
# 29998  29999    80000.0    1          3         1  41.0      1     -1      0
# 29999  30000    50000.0    1          2         1  46.0      0      0      0
#
# ...

# %%
final=merged.drop(['LIMIT_BAL'],axis='columns')

# %%
final
# Out:
#           ID  SEX  EDUCATION  MARRIAGE   AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0          1    2          2         1  24.0      2      2     -1     -1
# 1          2    2          2         2  26.0     -1      2      0      0
# 2          3    2          2         2   NaN      0      0      0      0
# 3          4    2          2         1   NaN      0      0      0      0
# 4          5    1          2         1  57.0     -1      0     -1      0
# ...      ...  ...        ...       ...   ...    ...    ...    ...    ...
# 29995  29996    1          3         1  39.0      0      0      0      0
# 29996  29997    1          3         2  43.0     -1     -1     -1     -1
# 29997  29998    1          2         2  37.0      4      3      2     -1
# 29998  29999    1          3         1  41.0      1     -1      0      0
# 29999  30000    1          2         1  46.0      0      0      0      0
#
#        PAY_5  ...  700000.0  710000.0  720000.0  730000.0  740000.0  750000.0  \
# ...

# %%
y= df['default.payment.next.month']

# %%
y
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 29995    0
# 29996    0
# 29997    1
# 29998    1
# 29999    1
# Name: default.payment.next.month, Length: 30000, dtype: int64

# %%
X = df.drop(['default.payment.next.month'],axis=1).fillna(0)

# %%
final.shape
# Out:
# (30000, 105)

# %%
final.columns
# Out:
# Index([       'ID',       'SEX', 'EDUCATION',  'MARRIAGE',       'AGE',
#            'PAY_0',     'PAY_2',     'PAY_3',     'PAY_4',     'PAY_5',
#        ...
#           700000.0,    710000.0,    720000.0,    730000.0,    740000.0,
#           750000.0,    760000.0,    780000.0,    800000.0,   1000000.0],
#       dtype='object', length=105)

# %%
X
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE   AGE  PAY_0  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1  24.0      2      2     -1
# 1          2   120000.0    2          2         2  26.0     -1      2      0
# 2          3    90000.0    2          2         2   0.0      0      0      0
# 3          4    50000.0    2          2         1   0.0      0      0      0
# 4          5    50000.0    1          2         1  57.0     -1      0     -1
# ...      ...        ...  ...        ...       ...   ...    ...    ...    ...
# 29995  29996   220000.0    1          3         1  39.0      0      0      0
# 29996  29997   150000.0    1          3         2  43.0     -1     -1     -1
# 29997  29998    30000.0    1          2         2  37.0      4      3      2
# 29998  29999    80000.0    1          3         1  41.0      1     -1      0
# 29999  30000    50000.0    1          2         1  46.0      0      0      0
#
# ...

# %%
fill= df['AGE'].median()
df.AGE = df.AGE.fillna(fill)

# %%
X.fillna(0)
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE   AGE  PAY_0  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1  24.0      2      2     -1
# 1          2   120000.0    2          2         2  26.0     -1      2      0
# 2          3    90000.0    2          2         2   0.0      0      0      0
# 3          4    50000.0    2          2         1   0.0      0      0      0
# 4          5    50000.0    1          2         1  57.0     -1      0     -1
# ...      ...        ...  ...        ...       ...   ...    ...    ...    ...
# 29995  29996   220000.0    1          3         1  39.0      0      0      0
# 29996  29997   150000.0    1          3         2  43.0     -1     -1     -1
# 29997  29998    30000.0    1          2         2  37.0      4      3      2
# 29998  29999    80000.0    1          3         1  41.0      1     -1      0
# 29999  30000    50000.0    1          2         1  46.0      0      0      0
#
# ...

# %%
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.30,random_state=1)

# %%
#Train Model
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(X_train, y_train)

#predict
reg.predict(X_test)
# Out:
# array([0.15525511, 0.15498731, 0.12236337, ..., 0.13516423, 0.15523171,
#        0.11572982])

# %%
plt.plot(X,reg.predict(X))

# %%
reg.coef_
# Out:
# array([-2.43143684e-08, -7.50360055e-08, -1.13095954e-02, -1.36561825e-02,
#        -2.39468651e-02,  1.47156481e-03,  9.51933961e-02,  2.34516934e-02,
#         7.31379723e-03,  5.19623625e-03,  6.58048844e-03, -1.72232009e-03,
#        -5.96814809e-07,  2.21625353e-07, -1.89966144e-07,  1.42883500e-07,
#        -1.47521801e-07,  1.80884861e-07, -6.99842578e-07, -8.96177382e-08,
#        -1.19862255e-07, -2.16588744e-07, -4.94606345e-07, -1.38262546e-07])

# %%
reg.intercept_
# Out:
# 0.30036742705886144

# %%
reg.score(X_test,y_test)
# Out:
# 0.12289413768460455

# %%
reg.predict([[72000,4,0,0,0,1,72000,4,0,0,0,1,72000,4,0,0,0,1,72000,4,0,0,0,1]])
# Out:
# C:\Users\arsha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([6854.22333248])

# %%
import seaborn
from sklearn.svm import SVC
r=SVC(gamma='auto')
r.fit(X_train, y_train)
pred2= r.predict(X_test)

# %%
from sklearn import metrics
confusion_matrix = metrics.confusion_matrix(y_test,pred2)
cm_display =metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix,display_labels=[False,True])
cm_display.plot()
plt.show()
